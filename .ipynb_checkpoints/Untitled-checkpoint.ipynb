# %%
import os
import yaml

from langchain.agents import create_json_agent, AgentExecutor
from langchain.agents.agent_toolkits import JsonToolkit
from langchain.chains import LLMChain
from langchain.llms.openai import OpenAI
from langchain.chat_models import ChatOpenAI
from langchain.requests import TextRequestsWrapper
from langchain.tools.json.tool import JsonSpec

# %%
os.environ["OPENAI_API_KEY"]= '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'
# openai.api_key = OPENAI_API_KEY

with open("/home/rachitt/qual-llm/survey_questions_1.json") as f:
    data = yaml.load(f, Loader=yaml.FullLoader)
json_spec = JsonSpec(dict_=data, max_value_length=4000)
json_toolkit = JsonToolkit(spec=json_spec)

json_agent_executor = create_json_agent(
    llm=ChatOpenAI(model="gpt-3.5-turbo-16k",temperature=0.3), toolkit=json_toolkit, verbose=True
)

# %%
json_agent_executor.run(
    "list all options and questions in the JSON?"
)
# Out:
# > Entering new AgentExecutor chain...
# Action: json_spec_list_keys
# Action Input: data
# Observation: ['projectID', 'questions']
# Thought:I see that there is a key called 'questions' in the JSON. I should use the `json_spec_list_keys` tool to see what keys exist under 'questions'.
# Action: json_spec_list_keys
# Action Input: data["questions"]
# Observation: ValueError('Value at path `data["questions"]` is not a dict, get the value directly.')
# Thought:The value at `data["questions"]` is not a dictionary. I should use the `json_spec_get_value` tool to see the value directly.
# Action: json_spec_get_value
# Action Input: data["questions"]
# Observation: [{'questionID': 'QID19', 'questionName': 'Q.yearborn', 'questionText': 'In what year were you born?', 'questionType': 'DROPDOWN', 'choices': ['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980', '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972', '1971', '1970', '1969', '1968', '1967', '1966', '1965', '1964', '1963', '1962', '1961', '1960', '1959', '1958', '1957', '1956', '1955', '1954', '1953', '1952', '1951', '1950', '1949', '1948', '1947', '1946', '1945', '1944', '1943', '1942', '1941', '1940', '1939', '1938', '1937', '1936', '1935', '1934', '1933', '1932', '1931', '1930', '1929', '1928', '1927', '1926', '1925', '1924', '1923', '1922', '1921', '1920']}, {'questionID': 'QID20', 'questionName': 'Q.gender', 'questionText': 'Gender: ', 'questionType': 'SINGLE SELECT', 'choices': ['Male', 'Female', 'Gender Variant/Non-conforming', 'Not listed', 'Prefer not to say']}, {'questionID': 'QID21', 'questionName': 'Q.ethnicity', 'questionText': 'Race/Ethnicity:(Select all that apply)', 'questionType': 'MULTI SELECT', 'choices': ['White or Caucasian', 'Black or African American', 'American Indian or Alaska Native', 'Asian', 'Hispanic', 'Native Hawaiian or Pacific Islander', 'Other (please specify):', 'Prefer not to say']}, {'questionID': 'QID34', 'questionName': 'Q5', 'questionText': 'What do you use to stream TV shows or movies? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Smart TV', 'Roku ', 'Chromecast', 'Firestick', 'Apple TV', 'Gaming console', 'Smartphone', 'Tablet', 'Laptop', 'Other (please specify)', 'I do not regularly stream TV shows or movies']}, {'questionID': 'QID35', 'questionName': 'Q6', 'questionText': 'Of the two options, how do you identify?', 'questionType': 'SINGLE SELECT', 'choices': ['Introvert', 'Extrovert']}, {'questionID': 'QID36', 'questionName': 'Q7', 'questionText': 'Which statement applies to you? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['I am a full time student', 'I am a full time student with a job', 'I am a part time student', 'I am a part time student with a job', 'I have a part time job', 'I have a full time job', 'None of the above']}, {'questionID': 'QID37', 'questionName': 'Q8', 'questionText': 'Which do you currently use? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Hulu', 'Netflix', 'Amazon Prime Video', 'YouTube Premium', 'Sling', 'Google TV+', 'Apple TV+', 'Disney+', 'Peacock', 'Paramount +', 'HBO Max', 'ESPN+', 'CuriosityStream', 'Discovery+', 'Crunchyroll', 'Funimation', 'FuboTV', 'Other (please specify)']}, {'questionID': 'QID38', 'questionName': 'Q9', 'questionText': 'Of the below list, which platform do you use the most, right now? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['Hulu', 'Netflix', 'Amazon Prime Video', 'YouTube Premium', 'Sling', 'Google TV+', 'Apple TV+', 'Disney+', 'Peacock', 'Paramount +', 'HBO Max', 'ESPN+', 'CuriosityStream', 'Discovery+', 'Crunchyroll', 'Funimation', 'FuboTV', 'Other (please specify)']}, {'questionID': 'QID39', 'questionName': 'Q10', 'questionText': 'Which do you currently use? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Iheartradio', 'Spotify', 'Deezer', 'Bandcamp', 'Tidal', 'Amazon Music', 'Apple Music', 'Stitcher', 'Audible', 'Pandora', 'SoundCloud', 'YouTube Music', 'Other (please specify)', "I don't regularly stream music"]}, {'questionID': 'QID40', 'questionName': 'Q11', 'questionText': 'Of the below list, which platform do you use the most, right now? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['Iheartradio', 'Spotify', 'Deezer', 'Bandcamp', 'Tidal', 'Amazon Music', 'Apple Music', 'Stitcher', 'Audible', 'Pandora', 'SoundCloud', 'YouT ...
# Thought:I have found the keys 'projectID' and 'questions' in the JSON. I should use the `json_spec_list_keys` tool to see what keys exist under 'questions'.
# Action: json_spec_list_keys
# Action Input: data["questions"]
# Observation: ValueError('Value at path `data["questions"]` is not a dict, get the value directly.')
# Thought:The value at `data["questions"]` is not a dictionary. I should use the `json_spec_get_value` tool to see the value directly.
# Action: json_spec_get_value
# Action Input: data["questions"]
# Observation: [{'questionID': 'QID19', 'questionName': 'Q.yearborn', 'questionText': 'In what year were you born?', 'questionType': 'DROPDOWN', 'choices': ['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980', '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972', '1971', '1970', '1969', '1968', '1967', '1966', '1965', '1964', '1963', '1962', '1961', '1960', '1959', '1958', '1957', '1956', '1955', '1954', '1953', '1952', '1951', '1950', '1949', '1948', '1947', '1946', '1945', '1944', '1943', '1942', '1941', '1940', '1939', '1938', '1937', '1936', '1935', '1934', '1933', '1932', '1931', '1930', '1929', '1928', '1927', '1926', '1925', '1924', '1923', '1922', '1921', '1920']}, {'questionID': 'QID20', 'questionName': 'Q.gender', 'questionText': 'Gender: ', 'questionType': 'SINGLE SELECT', 'choices': ['Male', 'Female', 'Gender Variant/Non-conforming', 'Not listed', 'Prefer not to say']}, {'questionID': 'QID21', 'questionName': 'Q.ethnicity', 'questionText': 'Race/Ethnicity:(Select all that apply)', 'questionType': 'MULTI SELECT', 'choices': ['White or Caucasian', 'Black or African American', 'American Indian or Alaska Native', 'Asian', 'Hispanic', 'Native Hawaiian or Pacific Islander', 'Other (please specify):', 'Prefer not to say']}, {'questionID': 'QID34', 'questionName': 'Q5', 'questionText': 'What do you use to stream TV shows or movies? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Smart TV', 'Roku ', 'Chromecast', 'Firestick', 'Apple TV', 'Gaming console', 'Smartphone', 'Tablet', 'Laptop', 'Other (please specify)', 'I do not regularly stream TV shows or movies']}, {'questionID': 'QID35', 'questionName': 'Q6', 'questionText': 'Of the two options, how do you identify?', 'questionType': 'SINGLE SELECT', 'choices': ['Introvert', 'Extrovert']}, {'questionID': 'QID36', 'questionName': 'Q7', 'questionText': 'Which statement applies to you? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['I am a full time student', 'I am a full time student with a job', 'I am a part time student', 'I am a part time student with a job', 'I have a part time job', 'I have a full time job', 'None of the above']}, {'questionID': 'QID37', 'questionName': 'Q8', 'questionText': 'Which do you currently use? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Hulu', 'Netflix', 'Amazon Prime Video', 'YouTube Premium', 'Sling', 'Google TV+', 'Apple TV+', 'Disney+', 'Peacock', 'Paramount +', 'HBO Max', 'ESPN+', 'CuriosityStream', 'Discovery+', 'Crunchyroll', 'Funimation', 'FuboTV', 'Other (please specify)']}, {'questionID': 'QID38', 'questionName': 'Q9', 'questionText': 'Of the below list, which platform do you use the most, right now? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['Hulu', 'Netflix', 'Amazon Prime Video', 'YouTube Premium', 'Sling', 'Google TV+', 'Apple TV+', 'Disney+', 'Peacock', 'Paramount +', 'HBO Max', 'ESPN+', 'CuriosityStream', 'Discovery+', 'Crunchyroll', 'Funimation', 'FuboTV', 'Other (please specify)']}, {'questionID': 'QID39', 'questionName': 'Q10', 'questionText': 'Which do you currently use? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Iheartradio', 'Spotify', 'Deezer', 'Bandcamp', 'Tidal', 'Amazon Music', 'Apple Music', 'Stitcher', 'Audible', 'Pandora', 'SoundCloud', 'YouTube Music', 'Other (please specify)', "I don't regularly stream music"]}, {'questionID': 'QID40', 'questionName': 'Q11', 'questionText': 'Of the below list, which platform do you use the most, right now? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['Iheartradio', 'Spotify', 'Deezer', 'Bandcamp', 'Tidal', 'Amazon Music', 'Apple Music', 'Stitcher', 'Audible', 'Pandora', 'SoundCloud', 'YouT ...
# Thought:I have found the keys 'projectID' and 'questions' in the JSON. I should use the `json_spec_list_keys` tool to see what keys exist under 'questions'.
# Action: json_spec_list_keys
# Action Input: data["questions"]
# Observation: ValueError('Value at path `data["questions"]` is not a dict, get the value directly.')
# Thought:The value at `data["questions"]` is not a dictionary. I should use the `json_spec_get_value` tool to see the value directly.
# Action: json_spec_get_value
# Action Input: data["questions"]
# Observation: [{'questionID': 'QID19', 'questionName': 'Q.yearborn', 'questionText': 'In what year were you born?', 'questionType': 'DROPDOWN', 'choices': ['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980', '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972', '1971', '1970', '1969', '1968', '1967', '1966', '1965', '1964', '1963', '1962', '1961', '1960', '1959', '1958', '1957', '1956', '1955', '1954', '1953', '1952', '1951', '1950', '1949', '1948', '1947', '1946', '1945', '1944', '1943', '1942', '1941', '1940', '1939', '1938', '1937', '1936', '1935', '1934', '1933', '1932', '1931', '1930', '1929', '1928', '1927', '1926', '1925', '1924', '1923', '1922', '1921', '1920']}, {'questionID': 'QID20', 'questionName': 'Q.gender', 'questionText': 'Gender: ', 'questionType': 'SINGLE SELECT', 'choices': ['Male', 'Female', 'Gender Variant/Non-conforming', 'Not listed', 'Prefer not to say']}, {'questionID': 'QID21', 'questionName': 'Q.ethnicity', 'questionText': 'Race/Ethnicity:(Select all that apply)', 'questionType': 'MULTI SELECT', 'choices': ['White or Caucasian', 'Black or African American', 'American Indian or Alaska Native', 'Asian', 'Hispanic', 'Native Hawaiian or Pacific Islander', 'Other (please specify):', 'Prefer not to say']}, {'questionID': 'QID34', 'questionName': 'Q5', 'questionText': 'What do you use to stream TV shows or movies? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Smart TV', 'Roku ', 'Chromecast', 'Firestick', 'Apple TV', 'Gaming console', 'Smartphone', 'Tablet', 'Laptop', 'Other (please specify)', 'I do not regularly stream TV shows or movies']}, {'questionID': 'QID35', 'questionName': 'Q6', 'questionText': 'Of the two options, how do you identify?', 'questionType': 'SINGLE SELECT', 'choices': ['Introvert', 'Extrovert']}, {'questionID': 'QID36', 'questionName': 'Q7', 'questionText': 'Which statement applies to you? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['I am a full time student', 'I am a full time student with a job', 'I am a part time student', 'I am a part time student with a job', 'I have a part time job', 'I have a full time job', 'None of the above']}, {'questionID': 'QID37', 'questionName': 'Q8', 'questionText': 'Which do you currently use? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Hulu', 'Netflix', 'Amazon Prime Video', 'YouTube Premium', 'Sling', 'Google TV+', 'Apple TV+', 'Disney+', 'Peacock', 'Paramount +', 'HBO Max', 'ESPN+', 'CuriosityStream', 'Discovery+', 'Crunchyroll', 'Funimation', 'FuboTV', 'Other (please specify)']}, {'questionID': 'QID38', 'questionName': 'Q9', 'questionText': 'Of the below list, which platform do you use the most, right now? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['Hulu', 'Netflix', 'Amazon Prime Video', 'YouTube Premium', 'Sling', 'Google TV+', 'Apple TV+', 'Disney+', 'Peacock', 'Paramount +', 'HBO Max', 'ESPN+', 'CuriosityStream', 'Discovery+', 'Crunchyroll', 'Funimation', 'FuboTV', 'Other (please specify)']}, {'questionID': 'QID39', 'questionName': 'Q10', 'questionText': 'Which do you currently use? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Iheartradio', 'Spotify', 'Deezer', 'Bandcamp', 'Tidal', 'Amazon Music', 'Apple Music', 'Stitcher', 'Audible', 'Pandora', 'SoundCloud', 'YouTube Music', 'Other (please specify)', "I don't regularly stream music"]}, {'questionID': 'QID40', 'questionName': 'Q11', 'questionText': 'Of the below list, which platform do you use the most, right now? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['Iheartradio', 'Spotify', 'Deezer', 'Bandcamp', 'Tidal', 'Amazon Music', 'Apple Music', 'Stitcher', 'Audible', 'Pandora', 'SoundCloud', 'YouT ...
# Thought:I have found the keys 'projectID' and 'questions' in the JSON. The 'questions' key contains a list of dictionaries, each representing a question. I should extract the 'questionText' and 'choices' keys from each dictionary to get all the options and questions in the JSON.
# Action: json_spec_get_value
# Action Input: data["questions"]
# Observation: [{'questionID': 'QID19', 'questionName': 'Q.yearborn', 'questionText': 'In what year were you born?', 'questionType': 'DROPDOWN', 'choices': ['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980', '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972', '1971', '1970', '1969', '1968', '1967', '1966', '1965', '1964', '1963', '1962', '1961', '1960', '1959', '1958', '1957', '1956', '1955', '1954', '1953', '1952', '1951', '1950', '1949', '1948', '1947', '1946', '1945', '1944', '1943', '1942', '1941', '1940', '1939', '1938', '1937', '1936', '1935', '1934', '1933', '1932', '1931', '1930', '1929', '1928', '1927', '1926', '1925', '1924', '1923', '1922', '1921', '1920']}, {'questionID': 'QID20', 'questionName': 'Q.gender', 'questionText': 'Gender: ', 'questionType': 'SINGLE SELECT', 'choices': ['Male', 'Female', 'Gender Variant/Non-conforming', 'Not listed', 'Prefer not to say']}, {'questionID': 'QID21', 'questionName': 'Q.ethnicity', 'questionText': 'Race/Ethnicity:(Select all that apply)', 'questionType': 'MULTI SELECT', 'choices': ['White or Caucasian', 'Black or African American', 'American Indian or Alaska Native', 'Asian', 'Hispanic', 'Native Hawaiian or Pacific Islander', 'Other (please specify):', 'Prefer not to say']}, {'questionID': 'QID34', 'questionName': 'Q5', 'questionText': 'What do you use to stream TV shows or movies? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Smart TV', 'Roku ', 'Chromecast', 'Firestick', 'Apple TV', 'Gaming console', 'Smartphone', 'Tablet', 'Laptop', 'Other (please specify)', 'I do not regularly stream TV shows or movies']}, {'questionID': 'QID35', 'questionName': 'Q6', 'questionText': 'Of the two options, how do you identify?', 'questionType': 'SINGLE SELECT', 'choices': ['Introvert', 'Extrovert']}, {'questionID': 'QID36', 'questionName': 'Q7', 'questionText': 'Which statement applies to you? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['I am a full time student', 'I am a full time student with a job', 'I am a part time student', 'I am a part time student with a job', 'I have a part time job', 'I have a full time job', 'None of the above']}, {'questionID': 'QID37', 'questionName': 'Q8', 'questionText': 'Which do you currently use? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Hulu', 'Netflix', 'Amazon Prime Video', 'YouTube Premium', 'Sling', 'Google TV+', 'Apple TV+', 'Disney+', 'Peacock', 'Paramount +', 'HBO Max', 'ESPN+', 'CuriosityStream', 'Discovery+', 'Crunchyroll', 'Funimation', 'FuboTV', 'Other (please specify)']}, {'questionID': 'QID38', 'questionName': 'Q9', 'questionText': 'Of the below list, which platform do you use the most, right now? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['Hulu', 'Netflix', 'Amazon Prime Video', 'YouTube Premium', 'Sling', 'Google TV+', 'Apple TV+', 'Disney+', 'Peacock', 'Paramount +', 'HBO Max', 'ESPN+', 'CuriosityStream', 'Discovery+', 'Crunchyroll', 'Funimation', 'FuboTV', 'Other (please specify)']}, {'questionID': 'QID39', 'questionName': 'Q10', 'questionText': 'Which do you currently use? Select all that apply.', 'questionType': 'MULTI SELECT', 'choices': ['Iheartradio', 'Spotify', 'Deezer', 'Bandcamp', 'Tidal', 'Amazon Music', 'Apple Music', 'Stitcher', 'Audible', 'Pandora', 'SoundCloud', 'YouTube Music', 'Other (please specify)', "I don't regularly stream music"]}, {'questionID': 'QID40', 'questionName': 'Q11', 'questionText': 'Of the below list, which platform do you use the most, right now? Select one.', 'questionType': 'SINGLE SELECT', 'choices': ['Iheartradio', 'Spotify', 'Deezer', 'Bandcamp', 'Tidal', 'Amazon Music', 'Apple Music', 'Stitcher', 'Audible', 'Pandora', 'SoundCloud', 'YouT ...
# Thought:I have extracted the 'questionText' and 'choices' keys from each question in the JSON. Now I can list all the options and questions.
# Final Answer:
# 1. In what year were you born? (Options: ['2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005', '2004', '2003', '2002', '2001', '2000', '1999', '1998', '1997', '1996', '1995', '1994', '1993', '1992', '1991', '1990', '1989', '1988', '1987', '1986', '1985', '1984', '1983', '1982', '1981', '1980', '1979', '1978', '1977', '1976', '1975', '1974', '1973', '1972', '1971', '1970', '1969', '1968', '1967', '1966', '1965', '1964', '1963', '1962', '1961', '1960', '1959', '1958', '1957', '1956', '1955', '1954', '1953', '1952', '1951', '1950', '1949', '1948', '1947', '1946', '1945', '1944', '1943', '1942', '1941', '1940', '1939', '1938', '1937', '1936', '1935', '1934', '1933', '1932', '1931', '1930', '1929', '1928', '1927', '1926', '1925', '1924', '1923', '1922', '1921', '1920'])
# 2. Gender:  (Options: ['Male', 'Female', 'Gender Variant/Non-conforming', 'Not listed', 'Prefer not to say'])
# 3. Race/Ethnicity:(Select all that apply) (Options: ['White or Caucasian', 'Black or African American', 'American Indian or Alaska Native', 'Asian', 'Hispanic', 'Native Hawaiian or Pacific Islander', 'Other (please specify):', 'Prefer not to say'])
# 4. What do you use to stream TV shows or movies? Select all that apply. (Options: ['Smart TV', 'Roku ', 'Chromecast', 'Firestick', 'Apple TV', 'Gaming console', 'Smartphone', 'Tablet', 'Laptop', 'Other (please specify)', 'I do not regularly stream TV shows or movies'])
# 5. Of the two options, how do you identify? (Options: ['Introvert', 'Extrovert'])
# 6. Which statement applies to you? Select one. (Options: ['I am a full time student', 'I am a full time student with a job', 'I am a part time student', 'I am a part time student with a job', 'I have a part time job', 'I have a full time job', 'None of the above'])
# 7. Which do you currently use? Select all that apply. (Options: ['Hulu', 'Netflix', 'Amazon Prime Video', 'YouTube Premium', 'Sling', 'Google TV+', 'Apple TV+', 'Disney+', 'Peacock', 'Paramount +', 'HBO Max', 'ESPN+', 'CuriosityStream', 'Discovery+', 'Crunchyroll', 'Funimation', 'FuboTV', 'Other (please specify)'])
# 8. Of the below list, which platform do you use the most, right now? Select one. (Options: ['Hulu', 'Netflix', 'Amazon Prime Video', 'YouTube Premium', 'Sling', 'Google TV+', 'Apple TV+', 'Disney+', 'Peacock', 'Paramount +', 'HBO Max', 'ESPN+', 'CuriosityStream', 'Discovery+', 'Crunchyroll', 'Funimation', 'FuboTV', 'Other (please specify)'])
# 9. Which do you currently use? Select all that apply. (Options: ['Iheartradio', 'Spotify', 'Deezer', 'Bandcamp', 'Tidal', 'Amazon Music', 'Apple Music', 'Stitcher', 'Audible', 'Pandora', 'SoundCloud', 'YouTube Music', 'Other (please specify)', "I don't regularly stream music"])
# 10. Of the below list, which platform do you use the most, right now? Select one. (Options: ['Iheartradio', 'Spotify', 'Deezer', 'Bandcamp', 'Tidal', 'Amazon Music', 'Apple Music', 'Stitcher', 'Audible', 'Pandora', 'SoundCloud', 'YouTube Music', '...
#
# > Finished chain.
# '1. In what year were you born? (Options: [\'2020\', \'2019\', \'2018\', \'2017\', \'2016\', \'2015\', \'2014\', \'2013\', \'2012\', \'2011\', \'2010\', \'2009\', \'2008\', \'2007\', \'2006\', \'2005\', \'2004\', \'2003\', \'2002\', \'2001\', \'2000\', \'1999\', \'1998\', \'1997\', \'1996\', \'1995\', \'1994\', \'1993\', \'1992\', \'1991\', \'1990\', \'1989\', \'1988\', \'1987\', \'1986\', \'1985\', \'1984\', \'1983\', \'1982\', \'1981\', \'1980\', \'1979\', \'1978\', \'1977\', \'1976\', \'1975\', \'1974\', \'1973\', \'1972\', \'1971\', \'1970\', \'1969\', \'1968\', \'1967\', \'1966\', \'1965\', \'1964\', \'1963\', \'1962\', \'1961\', \'1960\', \'1959\', \'1958\', \'1957\', \'1956\', \'1955\', \'1954\', \'1953\', \'1952\', \'1951\', \'1950\', \'1949\', \'1948\', \'1947\', \'1946\', \'1945\', \'1944\', \'1943\', \'1942\', \'1941\', \'1940\', \'1939\', \'1938\', \'1937\', \'1936\', \'1935\', \'1934\', \'1933\', \'1932\', \'1931\', \'1930\', \'1929\', \'1928\', \'1927\', \'1926\', \'1925\', \'1924\', \'1923\', \'1922\', \'1921\', \'1920\'])\n2. Gender:  (Options: [\'Male\', \'Female\', \'Gender Variant/Non-conforming\', \'Not listed\', \'Prefer not to say\'])\n3. Race/Ethnicity:(Select all that apply) (Options: [\'White or Caucasian\', \'Black or African American\', \'American Indian or Alaska Native\', \'Asian\', \'Hispanic\', \'Native Hawaiian or Pacific Islander\', \'Other (please specify):\', \'Prefer not to say\'])\n4. What do you use to stream TV shows or movies? Select all that apply. (Options: [\'Smart TV\', \'Roku \', \'Chromecast\', \'Firestick\', \'Apple TV\', \'Gaming console\', \'Smartphone\', \'Tablet\', \'Laptop\', \'Other (please specify)\', \'I do not regularly stream TV shows or movies\'])\n5. Of the two options, how do you identify? (Options: [\'Introvert\', \'Extrovert\'])\n6. Which statement applies to you? Select one. (Options: [\'I am a full time student\', \'I am a full time student with a job\', \'I am a part time student\', \'I am a part time student with a job\', \'I have a part time job\', \'I have a full time job\', \'None of the above\'])\n7. Which do you currently use? Select all that apply. (Options: [\'Hulu\', \'Netflix\', \'Amazon Prime Video\', \'YouTube Premium\', \'Sling\', \'Google TV+\', \'Apple TV+\', \'Disney+\', \'Peacock\', \'Paramount +\', \'HBO Max\', \'ESPN+\', \'CuriosityStream\', \'Discovery+\', \'Crunchyroll\', \'Funimation\', \'FuboTV\', \'Other (please specify)\'])\n8. Of the below list, which platform do you use the most, right now? Select one. (Options: [\'Hulu\', \'Netflix\', \'Amazon Prime Video\', \'YouTube Premium\', \'Sling\', \'Google TV+\', \'Apple TV+\', \'Disney+\', \'Peacock\', \'Paramount +\', \'HBO Max\', \'ESPN+\', \'CuriosityStream\', \'Discovery+\', \'Crunchyroll\', \'Funimation\', \'FuboTV\', \'Other (please specify)\'])\n9. Which do you currently use? Select all that apply. (Options: [\'Iheartradio\', \'Spotify\', \'Deezer\', \'Bandcamp\', \'Tidal\', \'Amazon Music\', \'Apple Music\', \'Stitcher\', \'Audible\', \'Pandora\', \'SoundCloud\', \'YouTube Music\', \'Other (please specify)\', "I don\'t regularly stream music"])\n10. Of the below list, which platform do you use the most, right now? Select one. (Options: [\'Iheartradio\', \'Spotify\', \'Deezer\', \'Bandcamp\', \'Tidal\', \'Amazon Music\', \'Apple Music\', \'Stitcher\', \'Audible\', \'Pandora\', \'SoundCloud\', \'YouTube Music\', \'...'

# %%
# !pip install pandas tabulate
# Out:
# Requirement already satisfied: pandas in ./qual/lib/python3.10/site-packages (1.5.3)
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./qual/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in ./qual/lib/python3.10/site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in ./qual/lib/python3.10/site-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in ./qual/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Installing collected packages: tabulate
# Successfully installed tabulate-0.9.0

# %%
import pandas as pd

def load_multiple_jsons_to_dataframe(file_paths):
    # Create an empty list to hold dataframes
    dfs = []

    for path in file_paths:
        # Load each JSON file into a DataFrame
        df = pd.read_json(path)
        dfs.append(df)

    # Concatenate all DataFrames together
    final_df = pd.concat(dfs, ignore_index=True)

    return final_df

# Example usage
file_paths = ["/home/rachitt/qual-llm/survey_questions_1.json", "/home/rachitt/qual-llm/survey_responses_1.json","/home/rachitt/qual-llm/survey_questions_2.json", "/home/rachitt/qual-llm/survey_responses_2.json"]
resulting_dataframe = load_multiple_jsons_to_dataframe(file_paths)

# %%
from langchain.agents import create_pandas_dataframe_agent
from langchain.chat_models import ChatOpenAI
from langchain.agents.agent_types import AgentType

# %%
import pandas as pd

# def load_multiple_jsons_to_dataframe(file_paths):
#     # Create an empty list to hold dataframes
#     dfs = []

#     for path in file_paths:
#         # Load each JSON file into a DataFrame
#         df = pd.read_json(path)
#         dfs.append(df)

#     # Concatenate all DataFrames together
#     final_df = pd.concat(dfs, ignore_index=True)

#     return final_df

# # Example usage
# file_paths = ["/home/rachitt/qual-llm/survey_questions_1.json", "/home/rachitt/qual-llm/survey_responses_1.json","/home/rachitt/qual-llm/survey_questions_2.json", "/home/rachitt/qual-llm/survey_responses_2.json"]
df = pd.read_json("/home/rachitt/qual-llm/combined_survey_data.json")
# Out:
#                                                            0    \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            1    \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            2    \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            3    \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            4    \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            5    \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            6    \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            7    \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            8    \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            9    \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            10   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            11   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            12   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            13   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            14   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            15   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            16   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            17   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            18   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            19   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            20   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            21   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            22   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            23   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            24   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            25   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            26   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            27   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            28   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            29   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            30   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            31   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            32   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            33   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            34   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            35   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            36   \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            249  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            250  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            251  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            252  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            253  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            254  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            255  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            256  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender          {'question': 'Gender: ', 'response': 'Male'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            257  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            258  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            259  \
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...
#
#                                                            260
# Q.yearborn   {'question': 'In what year were you born?', 'r...
# Q.gender        {'question': 'Gender: ', 'response': 'Female'}
# Q.ethnicity  {'question': 'Race/Ethnicity:(Select all that ...
# Q5           {'question': 'What do you use to stream TV sho...
# Q6           {'question': 'Of the two options, how do you i...
# Q7           {'question': 'Which statement applies to you? ...
# Q8           {'question': 'Which do you currently use? Sele...
# Q9           {'question': 'Of the below list, which platfor...
# Q10          {'question': 'Which do you currently use? Sele...
# Q11          {'question': 'Of the below list, which platfor...
# Q12          {'question': 'Which statement best applies to ...
# Q13          {'question': 'Have you canceled a streaming su...
# Q15          {'question': 'Why did you cancel the streaming...
# Q19          {'question': 'Of the below list, which is your...
# Q20          {'question': 'When you are streaming a TV show...
# Q21          {'question': 'When you are streaming a TV show...
# Q22          {'question': 'When you discover a new TV show ...
# Q23          {'question': 'How important is it to you to be...
# Q24          {'question': 'Of the below, which do you prefe...

# %%
agent = create_pandas_dataframe_agent(ChatOpenAI(model="gpt-3.5-turbo-16k",temperature=0.3), df, verbose=True)

# %%
agent.run("what are the major races of the users? Show by a chart")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 agent.run("what are the major races of the users? Show by a chart")
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chains/base.py:451, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     449     if len(args) != 1:
#     450         raise ValueError("`run` supports only one positional argument.")
# --> 451     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     452         _output_key
#     453     ]
#     455 if kwargs and not args:
#     456     return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     457         _output_key
#     458     ]
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chains/base.py:258, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     256 except (KeyboardInterrupt, Exception) as e:
#     257     run_manager.on_chain_error(e)
# --> 258     raise e
#     259 run_manager.on_chain_end(outputs)
#     260 final_outputs: Dict[str, Any] = self.prep_outputs(
#     261     inputs, outputs, return_only_outputs
#     262 )
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chains/base.py:252, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     246 run_manager = callback_manager.on_chain_start(
#     247     dumpd(self),
#     248     inputs,
#     249 )
#     250 try:
#     251     outputs = (
# --> 252         self._call(inputs, run_manager=run_manager)
#     253         if new_arg_supported
#     254         else self._call(inputs)
#     255     )
#     256 except (KeyboardInterrupt, Exception) as e:
#     257     run_manager.on_chain_error(e)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/agents/agent.py:1035, in AgentExecutor._call(self, inputs, run_manager)
#    1033 # We now enter the agent loop (until it returns something).
#    1034 while self._should_continue(iterations, time_elapsed):
# -> 1035     next_step_output = self._take_next_step(
#    1036         name_to_tool_map,
#    1037         color_mapping,
#    1038         inputs,
#    1039         intermediate_steps,
#    1040         run_manager=run_manager,
#    1041     )
#    1042     if isinstance(next_step_output, AgentFinish):
#    1043         return self._return(
#    1044             next_step_output, intermediate_steps, run_manager=run_manager
#    1045         )
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/agents/agent.py:832, in AgentExecutor._take_next_step(self, name_to_tool_map, color_mapping, inputs, intermediate_steps, run_manager)
#     829     intermediate_steps = self._prepare_intermediate_steps(intermediate_steps)
#     831     # Call the LLM to see what to do.
# --> 832     output = self.agent.plan(
#     833         intermediate_steps,
#     834         callbacks=run_manager.get_child() if run_manager else None,
#     835         **inputs,
#     836     )
#     837 except OutputParserException as e:
#     838     if isinstance(self.handle_parsing_errors, bool):
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/agents/agent.py:456, in Agent.plan(self, intermediate_steps, callbacks, **kwargs)
#     444 """Given input, decided what to do.
#     445
#     446 Args:
#    (...)
#     453     Action specifying what tool to use.
#     454 """
#     455 full_inputs = self.get_full_inputs(intermediate_steps, **kwargs)
# --> 456 full_output = self.llm_chain.predict(callbacks=callbacks, **full_inputs)
#     457 return self.output_parser.parse(full_output)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chains/llm.py:252, in LLMChain.predict(self, callbacks, **kwargs)
#     237 def predict(self, callbacks: Callbacks = None, **kwargs: Any) -> str:
#     238     """Format prompt with kwargs and pass to LLM.
#     239
#     240     Args:
#    (...)
#     250             completion = llm.predict(adjective="funny")
#     251     """
# --> 252     return self(kwargs, callbacks=callbacks)[self.output_key]
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chains/base.py:258, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     256 except (KeyboardInterrupt, Exception) as e:
#     257     run_manager.on_chain_error(e)
# --> 258     raise e
#     259 run_manager.on_chain_end(outputs)
#     260 final_outputs: Dict[str, Any] = self.prep_outputs(
#     261     inputs, outputs, return_only_outputs
#     262 )
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chains/base.py:252, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, include_run_info)
#     246 run_manager = callback_manager.on_chain_start(
#     247     dumpd(self),
#     248     inputs,
#     249 )
#     250 try:
#     251     outputs = (
# --> 252         self._call(inputs, run_manager=run_manager)
#     253         if new_arg_supported
#     254         else self._call(inputs)
#     255     )
#     256 except (KeyboardInterrupt, Exception) as e:
#     257     run_manager.on_chain_error(e)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chains/llm.py:92, in LLMChain._call(self, inputs, run_manager)
#      87 def _call(
#      88     self,
#      89     inputs: Dict[str, Any],
#      90     run_manager: Optional[CallbackManagerForChainRun] = None,
#      91 ) -> Dict[str, str]:
# ---> 92     response = self.generate([inputs], run_manager=run_manager)
#      93     return self.create_outputs(response)[0]
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chains/llm.py:102, in LLMChain.generate(self, input_list, run_manager)
#     100 """Generate LLM result from inputs."""
#     101 prompts, stop = self.prep_prompts(input_list, run_manager=run_manager)
# --> 102 return self.llm.generate_prompt(
#     103     prompts,
#     104     stop,
#     105     callbacks=run_manager.get_child() if run_manager else None,
#     106     **self.llm_kwargs,
#     107 )
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chat_models/base.py:401, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     393 def generate_prompt(
#     394     self,
#     395     prompts: List[PromptValue],
#    (...)
#     398     **kwargs: Any,
#     399 ) -> LLMResult:
#     400     prompt_messages = [p.to_messages() for p in prompts]
# --> 401     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chat_models/base.py:296, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, **kwargs)
#     294         if run_managers:
#     295             run_managers[i].on_llm_error(e)
# --> 296         raise e
#     297 flattened_outputs = [
#     298     LLMResult(generations=[res.generations], llm_output=res.llm_output)
#     299     for res in results
#     300 ]
#     301 llm_output = self._combine_llm_outputs([res.llm_output for res in results])
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chat_models/base.py:286, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, **kwargs)
#     283 for i, m in enumerate(messages):
#     284     try:
#     285         results.append(
# --> 286             self._generate_with_cache(
#     287                 m,
#     288                 stop=stop,
#     289                 run_manager=run_managers[i] if run_managers else None,
#     290                 **kwargs,
#     291             )
#     292         )
#     293     except (KeyboardInterrupt, Exception) as e:
#     294         if run_managers:
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chat_models/base.py:433, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#     429     raise ValueError(
#     430         "Asked to cache, but no cache found at `langchain.cache`."
#     431     )
#     432 if new_arg_supported:
# --> 433     return self._generate(
#     434         messages, stop=stop, run_manager=run_manager, **kwargs
#     435     )
#     436 else:
#     437     return self._generate(messages, stop=stop, **kwargs)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chat_models/openai.py:400, in ChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#     398 message_dicts, params = self._create_message_dicts(messages, stop)
#     399 params = {**params, **kwargs}
# --> 400 response = self.completion_with_retry(
#     401     messages=message_dicts, run_manager=run_manager, **params
#     402 )
#     403 return self._create_chat_result(response)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chat_models/openai.py:340, in ChatOpenAI.completion_with_retry(self, run_manager, **kwargs)
#     336 @retry_decorator
#     337 def _completion_with_retry(**kwargs: Any) -> Any:
#     338     return self.client.create(**kwargs)
# --> 340 return _completion_with_retry(**kwargs)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/tenacity/__init__.py:289, in BaseRetrying.wraps.<locals>.wrapped_f(*args, **kw)
#     287 @functools.wraps(f)
#     288 def wrapped_f(*args: t.Any, **kw: t.Any) -> t.Any:
# --> 289     return self(f, *args, **kw)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/tenacity/__init__.py:379, in Retrying.__call__(self, fn, *args, **kwargs)
#     377 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     378 while True:
# --> 379     do = self.iter(retry_state=retry_state)
#     380     if isinstance(do, DoAttempt):
#     381         try:
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/tenacity/__init__.py:314, in BaseRetrying.iter(self, retry_state)
#     312 is_explicit_retry = fut.failed and isinstance(fut.exception(), TryAgain)
#     313 if not (is_explicit_retry or self.retry(retry_state)):
# --> 314     return fut.result()
#     316 if self.after is not None:
#     317     self.after(retry_state)
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:451, in Future.result(self, timeout)
#     449     raise CancelledError()
#     450 elif self._state == FINISHED:
# --> 451     return self.__get_result()
#     453 self._condition.wait(timeout)
#     455 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File /usr/lib/python3.10/concurrent/futures/_base.py:403, in Future.__get_result(self)
#     401 if self._exception:
#     402     try:
# --> 403         raise self._exception
#     404     finally:
#     405         # Break a reference cycle with the exception in self._exception
#     406         self = None
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/tenacity/__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     380 if isinstance(do, DoAttempt):
#     381     try:
# --> 382         result = fn(*args, **kwargs)
#     383     except BaseException:  # noqa: B902
#     384         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/chat_models/openai.py:338, in ChatOpenAI.completion_with_retry.<locals>._completion_with_retry(**kwargs)
#     336 @retry_decorator
#     337 def _completion_with_retry(**kwargs: Any) -> Any:
# --> 338     return self.client.create(**kwargs)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/openai/api_resources/chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/openai/api_resources/abstract/engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/openai/api_requestor.py:298, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
#     288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#    (...)
#     296         request_timeout=request_timeout,
#     297     )
# --> 298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/openai/api_requestor.py:700, in APIRequestor._interpret_response(self, result, stream)
#     692     return (
#     693         self._interpret_response_line(
#     694             line, result.status_code, result.headers, stream=True
#     695         )
#     696         for line in parse_stream(result.iter_lines())
#     697     ), True
#     698 else:
#     699     return (
# --> 700         self._interpret_response_line(
#     701             result.content.decode("utf-8"),
#     702             result.status_code,
#     703             result.headers,
#     704             stream=False,
#     705         ),
#     706         False,
#     707     )
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/openai/api_requestor.py:763, in APIRequestor._interpret_response_line(self, rbody, rcode, rheaders, stream)
#     761 stream_error = stream and "error" in resp.data
#     762 if stream_error or not 200 <= rcode < 300:
# --> 763     raise self.handle_error_response(
#     764         rbody, rcode, resp.data, rheaders, stream_error=stream_error
#     765     )
#     766 return resp
#
# InvalidRequestError: This model's maximum context length is 16385 tokens. However, your messages resulted in 35374 tokens. Please reduce the length of the messages.

# %%
# !pip install unstructured sentence_transformers
# Out:
# Requirement already satisfied: unstructured in ./qual/lib/python3.10/site-packages (0.9.1)
# Collecting sentence_transformers
#   Using cached sentence_transformers-2.2.2-py3-none-any.whl
# Requirement already satisfied: nltk in ./qual/lib/python3.10/site-packages (from unstructured) (3.8.1)
# Requirement already satisfied: chardet in ./qual/lib/python3.10/site-packages (from unstructured) (5.2.0)
# Requirement already satisfied: tabulate in ./qual/lib/python3.10/site-packages (from unstructured) (0.9.0)
# Requirement already satisfied: lxml in ./qual/lib/python3.10/site-packages (from unstructured) (4.9.3)
# Requirement already satisfied: filetype in ./qual/lib/python3.10/site-packages (from unstructured) (1.2.0)
# Requirement already satisfied: requests in ./qual/lib/python3.10/site-packages (from unstructured) (2.31.0)
# Requirement already satisfied: python-magic in ./qual/lib/python3.10/site-packages (from unstructured) (0.4.27)
# Collecting torch>=1.6.0
#   Using cached torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
# Collecting torchvision
#   Using cached torchvision-0.15.2-cp310-cp310-manylinux1_x86_64.whl (6.0 MB)
# Collecting huggingface-hub>=0.4.0
#   Using cached huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
# Collecting scikit-learn
#   Using cached scikit_learn-1.3.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
# Collecting transformers<5.0.0,>=4.6.0
#   Using cached transformers-4.31.0-py3-none-any.whl (7.4 MB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Requirement already satisfied: tqdm in ./qual/lib/python3.10/site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: numpy in ./qual/lib/python3.10/site-packages (from sentence_transformers) (1.25.2)
# Collecting scipy
#   Using cached scipy-1.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (36.3 MB)
# Requirement already satisfied: packaging>=20.9 in ./qual/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Collecting fsspec
#   Using cached fsspec-2023.6.0-py3-none-any.whl (163 kB)
# Requirement already satisfied: pyyaml>=5.1 in ./qual/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0.1)
# Collecting filelock
#   Using cached filelock-3.12.2-py3-none-any.whl (10 kB)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./qual/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.7.1)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-nvtx-cu11==11.7.91
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-nccl-cu11==2.14.3
#   Using cached nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
# Collecting triton==2.0.0
#   Using cached triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# Collecting networkx
#   Using cached networkx-3.1-py3-none-any.whl (2.1 MB)
# Requirement already satisfied: jinja2 in ./qual/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting nvidia-curand-cu11==10.2.10.91
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting sympy
#   Using cached sympy-1.12-py3-none-any.whl (5.7 MB)
# Requirement already satisfied: wheel in ./qual/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence_transformers) (0.37.1)
# Requirement already satisfied: setuptools in ./qual/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch>=1.6.0->sentence_transformers) (59.6.0)
# Collecting cmake
#   Downloading cmake-3.27.1-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (26.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.0/26.0 MB 2.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting lit
#   Using cached lit-16.0.6-py3-none-any.whl
# Requirement already satisfied: regex!=2019.12.17 in ./qual/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.6.3)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Collecting safetensors>=0.3.1
#   Downloading safetensors-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 2.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: click in ./qual/lib/python3.10/site-packages (from nltk->unstructured) (8.1.6)
# Requirement already satisfied: joblib in ./qual/lib/python3.10/site-packages (from nltk->unstructured) (1.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in ./qual/lib/python3.10/site-packages (from requests->unstructured) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./qual/lib/python3.10/site-packages (from requests->unstructured) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./qual/lib/python3.10/site-packages (from requests->unstructured) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./qual/lib/python3.10/site-packages (from requests->unstructured) (3.2.0)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.2.0-py3-none-any.whl (15 kB)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in ./qual/lib/python3.10/site-packages (from torchvision->sentence_transformers) (10.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./qual/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Collecting mpmath>=0.19
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: tokenizers, sentencepiece, safetensors, mpmath, lit, cmake, threadpoolctl, sympy, scipy, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, networkx, fsspec, filelock, scikit-learn, nvidia-cusolver-cu11, nvidia-cudnn-cu11, huggingface-hub, transformers, triton, torch, torchvision, sentence_transformers
# Successfully installed cmake-3.27.1 filelock-3.12.2 fsspec-2023.6.0 huggingface-hub-0.16.4 lit-16.0.6 mpmath-1.3.0 networkx-3.1 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 safetensors-0.3.2 scikit-learn-1.3.0 scipy-1.11.1 sentence_transformers-2.2.2 sentencepiece-0.1.99 sympy-1.12 threadpoolctl-3.2.0 tokenizers-0.13.3 torch-2.0.1 torchvision-0.15.2 transformers-4.31.0 triton-2.0.0

# %%
# !pip install chromadb
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.5-py3-none-any.whl (402 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 402.8/402.8 KB 3.0 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in ./qual/lib/python3.10/site-packages (from chromadb) (0.22.0)
# Collecting onnxruntime>=1.14.1
#   Using cached onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
# Requirement already satisfied: tokenizers>=0.13.2 in ./qual/lib/python3.10/site-packages (from chromadb) (0.13.3)
# Collecting pypika>=0.48.9
#   Using cached PyPika-0.48.9-py2.py3-none-any.whl
# Requirement already satisfied: requests>=2.28 in ./qual/lib/python3.10/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.5.0 in ./qual/lib/python3.10/site-packages (from chromadb) (4.7.1)
# Collecting importlib-resources
#   Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: fastapi<0.100.0,>=0.95.2 in ./qual/lib/python3.10/site-packages (from chromadb) (0.97.0)
# Requirement already satisfied: posthog>=2.4.0 in ./qual/lib/python3.10/site-packages (from chromadb) (3.0.1)
# Collecting pulsar-client>=3.1.0
#   Using cached pulsar_client-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
# Requirement already satisfied: overrides>=7.3.1 in ./qual/lib/python3.10/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: numpy>=1.21.6 in ./qual/lib/python3.10/site-packages (from chromadb) (1.25.2)
# Requirement already satisfied: pydantic<2.0,>=1.9 in ./qual/lib/python3.10/site-packages (from chromadb) (1.10.12)
# Requirement already satisfied: tqdm>=4.65.0 in ./qual/lib/python3.10/site-packages (from chromadb) (4.65.0)
# Collecting chroma-hnswlib==0.7.2
#   Downloading chroma-hnswlib-0.7.2.tar.gz (31 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in ./qual/lib/python3.10/site-packages (from fastapi<0.100.0,>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: packaging in ./qual/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (23.1)
# Collecting coloredlogs
#   Using cached coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
# Requirement already satisfied: protobuf in ./qual/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (4.23.4)
# Requirement already satisfied: sympy in ./qual/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Collecting flatbuffers
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: six>=1.5 in ./qual/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Requirement already satisfied: monotonic>=1.5 in ./qual/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: python-dateutil>2.1 in ./qual/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (2.8.2)
# Requirement already satisfied: backoff>=1.10.0 in ./qual/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: certifi in ./qual/lib/python3.10/site-packages (from pulsar-client>=3.1.0->chromadb) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./qual/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in ./qual/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./qual/lib/python3.10/site-packages (from requests>=2.28->chromadb) (2.0.4)
# Requirement already satisfied: click>=7.0 in ./qual/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.1.6)
# Requirement already satisfied: h11>=0.8 in ./qual/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Collecting uvloop!=0.15.0,!=0.15.1,>=0.14.0
#   Using cached uvloop-0.17.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.1 MB)
# Requirement already satisfied: watchfiles>=0.13 in ./qual/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: pyyaml>=5.1 in ./qual/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0.1)
# Collecting httptools>=0.5.0
#   Using cached httptools-0.6.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (428 kB)
# Requirement already satisfied: python-dotenv>=0.13 in ./qual/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: websockets>=10.4 in ./qual/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: anyio<5,>=3.4.0 in ./qual/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (3.7.1)
# Collecting humanfriendly>=9.1
#   Using cached humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: mpmath>=0.19 in ./qual/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in ./qual/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in ./qual/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.1.2)
# Building wheels for collected packages: chroma-hnswlib
#   Building wheel for chroma-hnswlib (pyproject.toml) ... done
#   Created wheel for chroma-hnswlib: filename=chroma_hnswlib-0.7.2-cp310-cp310-linux_x86_64.whl size=2285459 sha256=bbc34929fda3dedf50fc50059fb54abe64c75affe6cd7d34eae1b994eb826a09
#   Stored in directory: /home/rachitt/.cache/pip/wheels/11/2b/0d/ee457f6782f75315bb5828d5c2dc5639d471afbd44a830b9dc
# Successfully built chroma-hnswlib
# Installing collected packages: pypika, flatbuffers, uvloop, pulsar-client, importlib-resources, humanfriendly, httptools, chroma-hnswlib, coloredlogs, onnxruntime, chromadb
# Successfully installed chroma-hnswlib-0.7.2 chromadb-0.4.5 coloredlogs-15.0.1 flatbuffers-23.5.26 httptools-0.6.0 humanfriendly-10.0 importlib-resources-6.0.1 onnxruntime-1.15.1 pulsar-client-3.2.0 pypika-0.48.9 uvloop-0.17.0

# %%
# import
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain.text_splitter import CharacterTextSplitter
from langchain.vectorstores import Chroma
from langchain.document_loaders import CSVLoader

# load the document and split it into chunks
loader = CSVLoader("/home/rachitt/qual-llm/improved_combined_survey_data.csv")
documents = loader.load()

# split it into chunks
text_splitter = CharacterTextSplitter(chunk_size=1000, chunk_overlap=0)
docs = text_splitter.split_documents(documents)

# create the open-source embedding function
embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

# load it into Chroma
db = Chroma.from_documents(docs, embedding_function)

# query it
query = "what are the JSONs about?"
docs = db.similarity_search(query)

# print results
print(docs[0].page_content)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[55], line 19
#      16 embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
#      18 # load it into Chroma
# ---> 19 db = Chroma.from_documents(docs, embedding_function)
#      21 # query it
#      22 query = "what are the JSONs about?"
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/vectorstores/chroma.py:603, in Chroma.from_documents(cls, documents, embedding, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     601 texts = [doc.page_content for doc in documents]
#     602 metadatas = [doc.metadata for doc in documents]
# --> 603 return cls.from_texts(
#     604     texts=texts,
#     605     embedding=embedding,
#     606     metadatas=metadatas,
#     607     ids=ids,
#     608     collection_name=collection_name,
#     609     persist_directory=persist_directory,
#     610     client_settings=client_settings,
#     611     client=client,
#     612     collection_metadata=collection_metadata,
#     613     **kwargs,
#     614 )
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/vectorstores/chroma.py:567, in Chroma.from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     539 """Create a Chroma vectorstore from a raw documents.
#     540
#     541 If a persist_directory is specified, the collection will be persisted there.
#    (...)
#     556     Chroma: Chroma vectorstore.
#     557 """
#     558 chroma_collection = cls(
#     559     collection_name=collection_name,
#     560     embedding_function=embedding,
#    (...)
#     565     **kwargs,
#     566 )
# --> 567 chroma_collection.add_texts(texts=texts, metadatas=metadatas, ids=ids)
#     568 return chroma_collection
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/vectorstores/chroma.py:187, in Chroma.add_texts(self, texts, metadatas, ids, **kwargs)
#     185 texts = list(texts)
#     186 if self._embedding_function is not None:
# --> 187     embeddings = self._embedding_function.embed_documents(texts)
#     188 if metadatas:
#     189     # fill metadatas with empty dicts if somebody
#     190     # did not specify metadata for all texts
#     191     length_diff = len(texts) - len(metadatas)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/langchain/embeddings/huggingface.py:77, in HuggingFaceEmbeddings.embed_documents(self, texts)
#      68 """Compute doc embeddings using a HuggingFace transformer model.
#      69
#      70 Args:
#    (...)
#      74     List of embeddings, one for each text.
#      75 """
#      76 texts = list(map(lambda x: x.replace("\n", " "), texts))
# ---> 77 embeddings = self.client.encode(texts, **self.encode_kwargs)
#      78 return embeddings.tolist()
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/sentence_transformers/SentenceTransformer.py:153, in SentenceTransformer.encode(self, sentences, batch_size, show_progress_bar, output_value, convert_to_numpy, convert_to_tensor, device, normalize_embeddings)
#     150 if device is None:
#     151     device = self._target_device
# --> 153 self.to(device)
#     155 all_embeddings = []
#     156 length_sorted_idx = np.argsort([-self._text_length(sen) for sen in sentences])
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/torch/nn/modules/module.py:1145, in Module.to(self, *args, **kwargs)
#    1141         return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                     non_blocking, memory_format=convert_to_format)
#    1143     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
# -> 1145 return self._apply(convert)
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
#     [... skipping similar frames: Module._apply at line 797 (1 times)]
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/torch/nn/modules/module.py:797, in Module._apply(self, fn)
#     795 def _apply(self, fn):
#     796     for module in self.children():
# --> 797         module._apply(fn)
#     799     def compute_should_use_set_data(tensor, tensor_applied):
#     800         if torch._has_compatible_shallow_copy_type(tensor, tensor_applied):
#     801             # If the new tensor has compatible tensor type as the existing tensor,
#     802             # the current behavior is to change the tensor in-place using `.data =`,
#    (...)
#     807             # global flag to let the user control whether they want the future
#     808             # behavior of overwriting the existing tensor or not.
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/torch/nn/modules/module.py:820, in Module._apply(self, fn)
#     816 # Tensors stored in modules are graph leaves, and we don't want to
#     817 # track autograd history of `param_applied`, so we have to use
#     818 # `with torch.no_grad():`
#     819 with torch.no_grad():
# --> 820     param_applied = fn(param)
#     821 should_use_set_data = compute_should_use_set_data(param, param_applied)
#     822 if should_use_set_data:
#
# File ~/qual-llm/qual/lib/python3.10/site-packages/torch/nn/modules/module.py:1143, in Module.to.<locals>.convert(t)
#    1140 if convert_to_format is not None and t.dim() in (4, 5):
#    1141     return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None,
#    1142                 non_blocking, memory_format=convert_to_format)
# -> 1143 return t.to(device, dtype if t.is_floating_point() or t.is_complex() else None, non_blocking)
#
# RuntimeError: CUDA error: unspecified launch failure
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
from langchain.agents import create_pandas_dataframe_agent
from langchain.chat_models import ChatOpenAI
from langchain.agents.agent_types import AgentType

# %%
from langchain.llms import OpenAI
import pandas as pd

df = pd.read_csv("/home/rachitt/qual-llm/improved_combined_survey_data.csv")

# %%
agent = create_pandas_dataframe_agent(ChatOpenAI(temperature=0), df, verbose=True)

# %%
agent.run("what are the birth year ranges of the responses")
# Out:
# > Entering new AgentExecutor chain...
# Thought: I need to extract the birth year ranges from the "Q.yearborn" column.
# Action: I will use the `unique()` function to get the unique values in the "Q.yearborn" column.
# Action Input: `df['Q.yearborn'].unique()`
# Observation: I will use the `unique()` function to get the unique values in the "Q.yearborn" column. is not a valid tool, try one of [python_repl_ast].
# Thought:I can use the `unique()` function in pandas to get the unique values in the "Q.yearborn" column.
# Action: python_repl_ast
# Action Input: `df['Q.yearborn'].unique()`
# Observation: ['In what year were you born?,2004' 'In what year were you born?,2000'
#  'In what year were you born?,1998' 'In what year were you born?,2002'
#  'In what year were you born?,2001' 'In what year were you born?,1999'
#  'In what year were you born?,1997' 'In what year were you born?,2003']
# Thought:The birth year ranges are 2004, 2000, 1998, 2002, 2001, 1999, 1997, and 2003.
# Final Answer: The birth year ranges of the responses are 2004, 2000, 1998, 2002, 2001, 1999, 1997, and 2003.
#
# > Finished chain.
# 'The birth year ranges of the responses are 2004, 2000, 1998, 2002, 2001, 1999, 1997, and 2003.'
